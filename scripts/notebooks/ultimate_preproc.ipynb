# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('../../raw_data/miercoles_316airports.csv')

# %%
data
# Out:
#         MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0          11   23            1      OO            FAT                 SEA
# 1           6    4            4      WN            MKE                 BWI
# 2           6    9            2      AS            SEA                 ANC
# 3          11    9            1      AA            JFK                 MIA
# 4           1    2            5      EV            IAH                 DTW
# ...       ...  ...          ...     ...            ...                 ...
# 714846     12   31            4      UA            IAH                 TPA
# 714847     12   31            4      UA            SFO                 LAX
# 714848     12   31            4      AA            MIA                 SAN
# 714849     12   31            4      NK            FLL                 IAG
# 714850     12   31            4      AA            SAN                 MIA
#
#         SCHEDULED_TIME  DISTANCE  SCHEDULED_ARRIVAL  CANCELLED
# ...
